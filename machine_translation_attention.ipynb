# %%
# !pip install -U future

# %% [markdown]
# # Necessary Imports and Installations

# %%
import os, sys
import keras.backend as K
from keras.models import Model
from __future__ import print_function, division
from keras.preprocessing.text import Tokenizer
from keras.layers import Input, LSTM, GRU, Dense, Embedding, \
  Bidirectional, RepeatVector, Concatenate, Activation, Dot, Lambda
import numpy as np
from builtins import range, input
from keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
from keras.layers import Embedding

# %%
try:
  import keras.backend as K
  if len(K.tensorflow_backend._get_available_gpus()) > 0:
    from keras.layers import CuDNNLSTM as LSTM
    from keras.layers import CuDNNGRU as GRU
except:
  pass

# %% [markdown]
# # Softmax
# Softmax gives us the probability distribution over each element for “how much to care”. Expectant  N x T x D shape.

# %%
def ot_soft_max(x):
  assert(K.ndim(x) > 2)
  e = K.exp(x - K.max(x, axis=1, keepdims=True))
  s = K.sum(e, axis=1, keepdims=True)
  return e / s

# %%
n_size_batch = 64
dim_latent_decoder = 400 
nepochs = 30
num_wrds_max = 20000
dim_latent = 400
dim_embedding = 100
samples_num = 20000

# %% [markdown]
# #Where we Store the Data
# Data Loading and keeping only a limited number of samples to avoid the model taking a long time to train.

# %%
sentences_inputs = [] #INITIAL LANGUAGE SENTENTCES
sentences_outputs = [] # LANGUAGE SENTNCES IN TARGETTED LANG
sentences_outputs_inputs = [] #offset by1f targ lang

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
b = 0
for line in open('/content/drive/My Drive/translation_files/hin.txt'):

  b += 1
  if b > samples_num:
    break


  if '\t' not in line:
    continue

  sentences_input, translation, *rest = line.rstrip().split('\t')

  # make the target i/p & o/p
  # using teacher forcing
  sentences_output = translation + ' <eos>'
  sentences_output_input = '<sos> ' + translation

  sentences_inputs.append(sentences_input)
  sentences_outputs.append(sentences_output)
  sentences_outputs_inputs.append(sentences_output_input)
# print("num samples:", len(sentences_inputs)) =2952
# Out:
# num samples: 2952

# %% [markdown]
# #Tokenize
# tokenize the inputs and outputs and fetch the word-to-index mapping for the i/p and o/p language. Filtering outputs such that we avoid removing special chars else it will be difficult to find end-of-sentence and start-of-sentence tokens. Padding the seqs to maxlen.

# %%
ips_toknisr = Tokenizer(num_words=num_wrds_max)
ips_toknisr.fit_on_texts(sentences_inputs)
seqs_ip = ips_toknisr.texts_to_sequences(sentences_inputs)


inputs_w2ind = ips_toknisr.word_index
# print(' %s different i/p tokens were found.' % len(inputs_w2ind))=2429

ip_mx_lnth = max(len(i) for i in seqs_ip)


op_tokniser = Tokenizer(num_words=num_wrds_max, filters='')
op_tokniser.fit_on_texts(sentences_outputs + sentences_outputs_inputs) # inefficient, oh well
target_sequences = op_tokniser.texts_to_sequences(sentences_outputs)
ip_target_seqs = op_tokniser.texts_to_sequences(sentences_outputs_inputs)

outputs_w2ind = op_tokniser.word_index
# print(' %s different output tokens we re foun d' % len(outputs_w2ind))3195

op_num_wrds = len(outputs_w2ind) + 1


trgt_lenth_mx = max(len(sn) for sn in target_sequences)

# %%
ip_encdr = pad_sequences(seqs_ip, maxlen=ip_mx_lnth)
print("encoder_data.shape:", ip_encdr.shape)
print("encoder_data[0]:", ip_encdr[0])

ip_dcdr = pad_sequences(ip_target_seqs, maxlen=trgt_lenth_mx, padding='post')
# print("decoder_data[0]:", ip_dcdr[0])
# print("decoder_data.shape:", ip_dcdr.shape)

trgt_dcdrs = pad_sequences(target_sequences, maxlen=trgt_lenth_mx, padding='post')

# %% [markdown]
# # storage of all pretrained word vecs

# %%
print('uploading word vectors   ')
wrd_to_vec = {}
with open(os.path.join('/content/drive/My Drive/translation_files/glove.6B.%sd.txt' % dim_embedding)) as o:
 
  for line in o:
    values = line.split()
    word = values[0]
    vec = np.asarray(values[1:], dtype='float32')
    wrd_to_vec[word] = vec
print('%s word vectors were found' % len(wrd_to_vec))
# Out:
# uploading word vectors
# 400000 word vectors were found

# %%
print('Filling pre-trained embeddings...')
num_words = min(num_wrds_max, len(inputs_w2ind) + 1)
embedding_matrix = np.zeros((num_words, dim_embedding))
for word, i in inputs_w2ind.items():
  if i < num_wrds_max:
    embedding_vector = wrd_to_vec.get(word)
    if embedding_vector is not None:
      # words not found in embedding index will be all zeros.
      embedding_matrix[i] = embedding_vector
# Out:
# Filling pre-trained embeddings...

# %%
# for embedding layer creation
embedding_layer = Embedding(
  num_words,
  dim_embedding,
  weights=[embedding_matrix],
  input_length=ip_mx_lnth,
  
)

# %%
trgt_dcdrs1_hot = np.zeros(
  (
    len(sentences_inputs),
    trgt_lenth_mx,
    op_num_wrds
  ),
  dtype='float32'
)

# initialize
for i, d in enumerate(trgt_dcdrs):
  for t, word in enumerate(d):
    if word > 0:
      trgt_dcdrs1_hot[i, t, word] = 1

# %%
ip_encdr_plshldr = Input(shape=(ip_mx_lnth,))
x = embedding_layer(ip_encdr_plshldr)
encoder = Bidirectional(LSTM(
  dim_latent,
  return_sequences=True,

))
encoder_outputs = encoder(x)


ip_dcdr_plshldr = Input(shape=(trgt_lenth_mx,))


decoder_embedding = Embedding(op_num_wrds, dim_embedding)
ip_dcdr_x = decoder_embedding(ip_dcdr_plshldr)

# %% [markdown]
# # Attention Layer
# Attention layers need to be global because they will be repeated Ty times at the decoder

# %%
layr_attention_rep = RepeatVector(ip_mx_lnth)
layr_attention_concatenatn = Concatenate(axis=-1)
dense_attention_1 = Dense(10, activation='tanh')
dense_attention_2 = Dense(1, activation=ot_soft_max)
attn_dot = Dot(axes=1) 
def one_step_attention(h, st_1):
 
 

  st_1 = layr_attention_rep(st_1)

 
  x = layr_attention_concatenatn([h, st_1])

  x = dense_attention_1(x)

  
  alphas = dense_attention_2(x)

  
  context = attn_dot([alphas, h])

  return context

# %%
lstm_dcdr = LSTM(dim_latent_decoder, return_state=True)
dense_dcdr = Dense(op_num_wrds, activation='softmax')

s_init = Input(shape=(dim_latent_decoder,), name='s0')
c_init = Input(shape=(dim_latent_decoder,), name='c0')
context_last_word_concat_layer = Concatenate(axis=2)





s = s_init
c = c_init


outputs = []
for t in range(trgt_lenth_mx): 
  context = one_step_attention(encoder_outputs, s)

  
  selector = Lambda(lambda x: x[:, t:t+1])
  xt = selector(ip_dcdr_x)
  

  ip_lstm_dcdr = context_last_word_concat_layer([context, xt])

  
  o, s, c = lstm_dcdr(ip_lstm_dcdr, initial_state=[s, c])

 
  op_dcdr = dense_dcdr(o)
  outputs.append(op_dcdr)

# %%
def trnspoz_stack(x):
  
  x = K.stack(x) 
  x = K.permute_dimensions(x, pattern=(1, 0, 2)) 
  return x

# %% [markdown]
# # Create the Model

# %%
stacker = Lambda(trnspoz_stack)
outputs = stacker(outputs)


model = Model(
  inputs=[
    ip_encdr_plshldr,
    ip_dcdr_plshldr,
    s_init, 
    c_init,
  ],
  outputs=outputs
)

# %%
def custom_loss(y_true, y_pred):
  
  mask = K.cast(y_true > 0, dtype='float32')
  out = mask * y_true * K.log(y_pred)
  return -K.sum(out) / K.sum(mask)


def acc(y_true, y_pred):
  
  targ = K.argmax(y_true, axis=-1)
  pred = K.argmax(y_pred, axis=-1)
  correct = K.cast(K.equal(targ, pred), dtype='float32')

 
  mask = K.cast(K.greater(targ, 0), dtype='float32')
  crct_n = K.sum(mask * correct)
  totl_n = K.sum(mask)
  return crct_n / totl_n

# %%
model.compile(optimizer='adam', loss=custom_loss, metrics=[acc])



z = np.zeros((len(ip_encdr), dim_latent_decoder)) 
r = model.fit(
  [ip_encdr, ip_dcdr, z, z], trgt_dcdrs1_hot,
  batch_size=n_size_batch,
  epochs=nepochs,
  validation_split=0.2
)
# Out:
# Epoch 1/30
# 37/37 [==============================] - 81s 738ms/step - loss: 0.4152 - acc: 0.9113 - val_loss: 9.4398 - val_acc: 0.1401
# Epoch 2/30
# 37/37 [==============================] - 13s 341ms/step - loss: 0.3465 - acc: 0.9217 - val_loss: 9.6220 - val_acc: 0.1384
# Epoch 3/30
# 37/37 [==============================] - 12s 339ms/step - loss: 0.3035 - acc: 0.9346 - val_loss: 9.5580 - val_acc: 0.1404
# Epoch 4/30
# 37/37 [==============================] - 13s 340ms/step - loss: 0.2827 - acc: 0.9365 - val_loss: 9.8978 - val_acc: 0.1405
# Epoch 5/30
# 37/37 [==============================] - 13s 339ms/step - loss: 0.2748 - acc: 0.9365 - val_loss: 9.8782 - val_acc: 0.1427
# Epoch 6/30
# 37/37 [==============================] - 13s 340ms/step - loss: 0.2743 - acc: 0.9356 - val_loss: 9.9637 - val_acc: 0.1418
# Epoch 7/30
# 37/37 [==============================] - 12s 336ms/step - loss: 0.2704 - acc: 0.9348 - val_loss: 9.8899 - val_acc: 0.1390
# Epoch 8/30
# 37/37 [==============================] - 13s 341ms/step - loss: 0.2704 - acc: 0.9324 - val_loss: 9.9351 - val_acc: 0.1371
# Epoch 9/30
# 37/37 [==============================] - 13s 341ms/step - loss: 0.2633 - acc: 0.9319 - val_loss: 9.8515 - val_acc: 0.1370
# Epoch 10/30
# 37/37 [==============================] - 13s 339ms/step - loss: 0.2358 - acc: 0.9374 - val_loss: 9.9382 - val_acc: 0.1387
# Epoch 11/30
# 37/37 [==============================] - 12s 335ms/step - loss: 0.2229 - acc: 0.9393 - val_loss: 9.9499 - val_acc: 0.1356
# Epoch 12/30
# 37/37 [==============================] - 13s 340ms/step - loss: 0.2225 - acc: 0.9386 - val_loss: 10.0843 - val_acc: 0.1404
# Epoch 13/30
# 37/37 [==============================] - 13s 341ms/step - loss: 0.2227 - acc: 0.9382 - val_loss: 10.1853 - val_acc: 0.1379
# Epoch 14/30
# 37/37 [==============================] - 13s 340ms/step - loss: 0.2164 - acc: 0.9384 - val_loss: 10.2607 - val_acc: 0.1365
# Epoch 15/30
# 37/37 [==============================] - 12s 337ms/step - loss: 0.1947 - acc: 0.9446 - val_loss: 10.1988 - val_acc: 0.1371
# Epoch 16/30
# 37/37 [==============================] - 12s 337ms/step - loss: 0.1827 - acc: 0.9462 - val_loss: 10.5487 - val_acc: 0.1389
# Epoch 17/30
# 37/37 [==============================] - 12s 338ms/step - loss: 0.1690 - acc: 0.9485 - val_loss: 10.5157 - val_acc: 0.1388
# Epoch 18/30
# 37/37 [==============================] - 13s 339ms/step - loss: 0.1582 - acc: 0.9513 - val_loss: 10.5643 - val_acc: 0.1397
# Epoch 19/30
# 37/37 [==============================] - 13s 339ms/step - loss: 0.1573 - acc: 0.9499 - val_loss: 10.7105 - val_acc: 0.1392
# Epoch 20/30
# 37/37 [==============================] - 12s 339ms/step - loss: 0.1724 - acc: 0.9440 - val_loss: 10.5510 - val_acc: 0.1363
# Epoch 21/30
# 37/37 [==============================] - 12s 338ms/step - loss: 0.1694 - acc: 0.9422 - val_loss: 10.6895 - val_acc: 0.1379
# Epoch 22/30
# 37/37 [==============================] - 12s 339ms/step - loss: 0.1616 - acc: 0.9457 - val_loss: 10.6984 - val_acc: 0.1398
# Epoch 23/30
# 37/37 [==============================] - 12s 337ms/step - loss: 0.1646 - acc: 0.9457 - val_loss: 10.5556 - val_acc: 0.1400
# Epoch 24/30
# 37/37 [==============================] - 13s 340ms/step - loss: 0.1606 - acc: 0.9487 - val_loss: 10.6705 - val_acc: 0.1397
# Epoch 25/30
# 37/37 [==============================] - 12s 339ms/step - loss: 0.1582 - acc: 0.9458 - val_loss: 10.8487 - val_acc: 0.1389
# Epoch 26/30
# 37/37 [==============================] - 12s 334ms/step - loss: 0.1544 - acc: 0.9470 - val_loss: 10.8437 - val_acc: 0.1393
# Epoch 27/30
# 37/37 [==============================] - 13s 339ms/step - loss: 0.1580 - acc: 0.9456 - val_loss: 10.6961 - val_acc: 0.1385
# Epoch 28/30
# 37/37 [==============================] - 12s 333ms/step - loss: 0.1533 - acc: 0.9477 - val_loss: 10.8413 - val_acc: 0.1392
# Epoch 29/30
# 37/37 [==============================] - 12s 333ms/step - loss: 0.1560 - acc: 0.9466 - val_loss: 10.9610 - val_acc: 0.1401
# Epoch 30/30
# 37/37 [==============================] - 12s 334ms/step - loss: 0.1641 - acc: 0.9423 - val_loss: 11.0427 - val_acc: 0.1375

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 22)]         0           []
#
#  embedding (Embedding)          (None, 22, 100)      243000      ['input_1[0][0]']
#
#  s0 (InputLayer)                [(None, 400)]        0           []
#
#  bidirectional (Bidirectional)  (None, 22, 800)      1603200     ['embedding[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 22, 400)      0           ['s0[0][0]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[5][1]',
#                                                                   'lstm_1[6][1]',
#                                                                   'lstm_1[7][1]',
#                                                                   'lstm_1[8][1]',
#                                                                   'lstm_1[9][1]',
#                                                                   'lstm_1[10][1]',
#                                                                   'lstm_1[11][1]',
#                                                                   'lstm_1[12][1]',
#                                                                   'lstm_1[13][1]',
#                                                                   'lstm_1[14][1]',
#                                                                   'lstm_1[15][1]',
#                                                                   'lstm_1[16][1]',
#                                                                   'lstm_1[17][1]',
#                                                                   'lstm_1[18][1]',
#                                                                   'lstm_1[19][1]',
#                                                                   'lstm_1[20][1]',
#                                                                   'lstm_1[21][1]',
#                                                                   'lstm_1[22][1]',
#                                                                   'lstm_1[23][1]',
#                                                                   'lstm_1[24][1]']
#
#  concatenate (Concatenate)      (None, 22, 1200)     0           ['bidirectional[0][0]',
#                                                                   'repeat_vector[0][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[1][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[2][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[3][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[4][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[5][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[6][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[7][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[8][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[9][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[10][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[11][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[12][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[13][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[14][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[15][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[16][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[17][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[18][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[19][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[20][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[21][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[22][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[23][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[24][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[25][0]']
#
#  dense (Dense)                  (None, 22, 10)       12010       ['concatenate[0][0]',
#                                                                   'concatenate[1][0]',
#                                                                   'concatenate[2][0]',
#                                                                   'concatenate[3][0]',
#                                                                   'concatenate[4][0]',
#                                                                   'concatenate[5][0]',
#                                                                   'concatenate[6][0]',
#                                                                   'concatenate[7][0]',
#                                                                   'concatenate[8][0]',
#                                                                   'concatenate[9][0]',
#                                                                   'concatenate[10][0]',
#                                                                   'concatenate[11][0]',
#                                                                   'concatenate[12][0]',
#                                                                   'concatenate[13][0]',
#                                                                   'concatenate[14][0]',
#                                                                   'concatenate[15][0]',
#                                                                   'concatenate[16][0]',
#                                                                   'concatenate[17][0]',
#                                                                   'concatenate[18][0]',
#                                                                   'concatenate[19][0]',
#                                                                   'concatenate[20][0]',
#                                                                   'concatenate[21][0]',
#                                                                   'concatenate[22][0]',
#                                                                   'concatenate[23][0]',
#                                                                   'concatenate[24][0]',
#                                                                   'concatenate[25][0]']
#
#  input_2 (InputLayer)           [(None, 26)]         0           []
#
#  dense_1 (Dense)                (None, 22, 1)        11          ['dense[0][0]',
#                                                                   'dense[1][0]',
#                                                                   'dense[2][0]',
#                                                                   'dense[3][0]',
#                                                                   'dense[4][0]',
#                                                                   'dense[5][0]',
#                                                                   'dense[6][0]',
#                                                                   'dense[7][0]',
#                                                                   'dense[8][0]',
#                                                                   'dense[9][0]',
#                                                                   'dense[10][0]',
#                                                                   'dense[11][0]',
#                                                                   'dense[12][0]',
#                                                                   'dense[13][0]',
#                                                                   'dense[14][0]',
#                                                                   'dense[15][0]',
#                                                                   'dense[16][0]',
#                                                                   'dense[17][0]',
#                                                                   'dense[18][0]',
#                                                                   'dense[19][0]',
#                                                                   'dense[20][0]',
#                                                                   'dense[21][0]',
#                                                                   'dense[22][0]',
#                                                                   'dense[23][0]',
#                                                                   'dense[24][0]',
#                                                                   'dense[25][0]']
#
#  embedding_1 (Embedding)        multiple             319600      ['input_2[0][0]']
#
#  dot (Dot)                      (None, 1, 800)       0           ['dense_1[0][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[1][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[2][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[3][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[4][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[5][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[6][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[7][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[8][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[9][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[10][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[11][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[12][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[13][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[14][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[15][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[16][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[17][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[18][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[19][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[20][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[21][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[22][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[23][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[24][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[25][0]',
#                                                                   'bidirectional[0][0]']
#
#  lambda (Lambda)                (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 900)       0           ['dot[0][0]',
#                                                                   'lambda[0][0]',
#                                                                   'dot[1][0]',
#                                                                   'lambda_1[0][0]',
#                                                                   'dot[2][0]',
#                                                                   'lambda_2[0][0]',
#                                                                   'dot[3][0]',
#                                                                   'lambda_3[0][0]',
#                                                                   'dot[4][0]',
#                                                                   'lambda_4[0][0]',
#                                                                   'dot[5][0]',
#                                                                   'lambda_5[0][0]',
#                                                                   'dot[6][0]',
#                                                                   'lambda_6[0][0]',
#                                                                   'dot[7][0]',
#                                                                   'lambda_7[0][0]',
#                                                                   'dot[8][0]',
#                                                                   'lambda_8[0][0]',
#                                                                   'dot[9][0]',
#                                                                   'lambda_9[0][0]',
#                                                                   'dot[10][0]',
#                                                                   'lambda_10[0][0]',
#                                                                   'dot[11][0]',
#                                                                   'lambda_11[0][0]',
#                                                                   'dot[12][0]',
#                                                                   'lambda_12[0][0]',
#                                                                   'dot[13][0]',
#                                                                   'lambda_13[0][0]',
#                                                                   'dot[14][0]',
#                                                                   'lambda_14[0][0]',
#                                                                   'dot[15][0]',
#                                                                   'lambda_15[0][0]',
#                                                                   'dot[16][0]',
#                                                                   'lambda_16[0][0]',
#                                                                   'dot[17][0]',
#                                                                   'lambda_17[0][0]',
#                                                                   'dot[18][0]',
#                                                                   'lambda_18[0][0]',
#                                                                   'dot[19][0]',
#                                                                   'lambda_19[0][0]',
#                                                                   'dot[20][0]',
#                                                                   'lambda_20[0][0]',
#                                                                   'dot[21][0]',
#                                                                   'lambda_21[0][0]',
#                                                                   'dot[22][0]',
#                                                                   'lambda_22[0][0]',
#                                                                   'dot[23][0]',
#                                                                   'lambda_23[0][0]',
#                                                                   'dot[24][0]',
#                                                                   'lambda_24[0][0]',
#                                                                   'dot[25][0]',
#                                                                   'lambda_25[0][0]']
#
#  c0 (InputLayer)                [(None, 400)]        0           []
#
#  lstm_1 (LSTM)                  [(None, 400),        2081600     ['concatenate_1[0][0]',
#                                  (None, 400),                     's0[0][0]',
#                                  (None, 400)]                     'c0[0][0]',
#                                                                   'concatenate_1[1][0]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[0][2]',
#                                                                   'concatenate_1[2][0]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[1][2]',
#                                                                   'concatenate_1[3][0]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[2][2]',
#                                                                   'concatenate_1[4][0]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[3][2]',
#                                                                   'concatenate_1[5][0]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[4][2]',
#                                                                   'concatenate_1[6][0]',
#                                                                   'lstm_1[5][1]',
#                                                                   'lstm_1[5][2]',
#                                                                   'concatenate_1[7][0]',
#                                                                   'lstm_1[6][1]',
#                                                                   'lstm_1[6][2]',
#                                                                   'concatenate_1[8][0]',
#                                                                   'lstm_1[7][1]',
#                                                                   'lstm_1[7][2]',
#                                                                   'concatenate_1[9][0]',
#                                                                   'lstm_1[8][1]',
#                                                                   'lstm_1[8][2]',
#                                                                   'concatenate_1[10][0]',
#                                                                   'lstm_1[9][1]',
#                                                                   'lstm_1[9][2]',
#                                                                   'concatenate_1[11][0]',
#                                                                   'lstm_1[10][1]',
#                                                                   'lstm_1[10][2]',
#                                                                   'concatenate_1[12][0]',
#                                                                   'lstm_1[11][1]',
#                                                                   'lstm_1[11][2]',
#                                                                   'concatenate_1[13][0]',
#                                                                   'lstm_1[12][1]',
#                                                                   'lstm_1[12][2]',
#                                                                   'concatenate_1[14][0]',
#                                                                   'lstm_1[13][1]',
#                                                                   'lstm_1[13][2]',
#                                                                   'concatenate_1[15][0]',
#                                                                   'lstm_1[14][1]',
#                                                                   'lstm_1[14][2]',
#                                                                   'concatenate_1[16][0]',
#                                                                   'lstm_1[15][1]',
#                                                                   'lstm_1[15][2]',
#                                                                   'concatenate_1[17][0]',
#                                                                   'lstm_1[16][1]',
#                                                                   'lstm_1[16][2]',
#                                                                   'concatenate_1[18][0]',
#                                                                   'lstm_1[17][1]',
#                                                                   'lstm_1[17][2]',
#                                                                   'concatenate_1[19][0]',
#                                                                   'lstm_1[18][1]',
#                                                                   'lstm_1[18][2]',
#                                                                   'concatenate_1[20][0]',
#                                                                   'lstm_1[19][1]',
#                                                                   'lstm_1[19][2]',
#                                                                   'concatenate_1[21][0]',
#                                                                   'lstm_1[20][1]',
#                                                                   'lstm_1[20][2]',
#                                                                   'concatenate_1[22][0]',
#                                                                   'lstm_1[21][1]',
#                                                                   'lstm_1[21][2]',
#                                                                   'concatenate_1[23][0]',
#                                                                   'lstm_1[22][1]',
#                                                                   'lstm_1[22][2]',
#                                                                   'concatenate_1[24][0]',
#                                                                   'lstm_1[23][1]',
#                                                                   'lstm_1[23][2]',
#                                                                   'concatenate_1[25][0]',
#                                                                   'lstm_1[24][1]',
#                                                                   'lstm_1[24][2]']
#
#  lambda_1 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_2 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_4 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_6 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_7 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_8 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_9 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_10 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_11 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_12 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_13 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_14 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_15 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_16 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_17 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_18 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_19 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_20 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_21 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_22 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_23 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_24 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_25 (Lambda)             (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  dense_2 (Dense)                (None, 3196)         1281596     ['lstm_1[0][0]',
#                                                                   'lstm_1[1][0]',
#                                                                   'lstm_1[2][0]',
#                                                                   'lstm_1[3][0]',
#                                                                   'lstm_1[4][0]',
#                                                                   'lstm_1[5][0]',
#                                                                   'lstm_1[6][0]',
#                                                                   'lstm_1[7][0]',
#                                                                   'lstm_1[8][0]',
#                                                                   'lstm_1[9][0]',
#                                                                   'lstm_1[10][0]',
#                                                                   'lstm_1[11][0]',
#                                                                   'lstm_1[12][0]',
#                                                                   'lstm_1[13][0]',
#                                                                   'lstm_1[14][0]',
#                                                                   'lstm_1[15][0]',
#                                                                   'lstm_1[16][0]',
#                                                                   'lstm_1[17][0]',
#                                                                   'lstm_1[18][0]',
#                                                                   'lstm_1[19][0]',
#                                                                   'lstm_1[20][0]',
#                                                                   'lstm_1[21][0]',
#                                                                   'lstm_1[22][0]',
#                                                                   'lstm_1[23][0]',
#                                                                   'lstm_1[24][0]',
#                                                                   'lstm_1[25][0]']
#
#  lambda_26 (Lambda)             (None, 26, 3196)     0           ['dense_2[0][0]',
#                                                                   'dense_2[1][0]',
#                                                                   'dense_2[2][0]',
#                                                                   'dense_2[3][0]',
#                                                                   'dense_2[4][0]',
#                                                                   'dense_2[5][0]',
#                                                                   'dense_2[6][0]',
#                                                                   'dense_2[7][0]',
#                                                                   'dense_2[8][0]',
#                                                                   'dense_2[9][0]',
#                                                                   'dense_2[10][0]',
#                                                                   'dense_2[11][0]',
#                                                                   'dense_2[12][0]',
#                                                                   'dense_2[13][0]',
#                                                                   'dense_2[14][0]',
#                                                                   'dense_2[15][0]',
#                                                                   'dense_2[16][0]',
#                                                                   'dense_2[17][0]',
#                                                                   'dense_2[18][0]',
#                                                                   'dense_2[19][0]',
#                                                                   'dense_2[20][0]',
#                                                                   'dense_2[21][0]',
#                                                                   'dense_2[22][0]',
#                                                                   'dense_2[23][0]',
#                                                                   'dense_2[24][0]',
#                                                                   'dense_2[25][0]']
#
# ==================================================================================================
# Total params: 5,541,017
# Trainable params: 5,541,017
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()


plt.plot(r.history['acc'], label='acc')
plt.plot(r.history['val_acc'], label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# # Make Predictions
# The encoder will be stand-alone</br>
# From this we will get our initial decoder </br>hidden state i.e. h(1), ..., h(Tx)

# %%
encoder_model = Model(ip_encdr_plshldr, encoder_outputs)


encoder_outputs_as_input = Input(shape=(ip_mx_lnth, dim_latent * 2,))
single_ip_dcdr = Input(shape=(1,))
single_ip_dcdr_x = decoder_embedding(single_ip_dcdr)


context = one_step_attention(encoder_outputs_as_input, s_init)


ip_lstm_dcdr = context_last_word_concat_layer([context, single_ip_dcdr_x])





o, s, c = lstm_dcdr(ip_lstm_dcdr, initial_state=[s_init, c_init])
op_dcdr = dense_dcdr(o)





decoder_model = Model(
  inputs=[
    single_ip_dcdr,
    encoder_outputs_as_input,
    s_init, 
    c_init
  ],
  outputs=[op_dcdr, s, c]
)




idx2word_eng = {v:k for k, v in inputs_w2ind.items()}
idx2word_trans = {v:k for k, v in outputs_w2ind.items()}





def dcdr_seq(input_seq):
  
  enc_out = encoder_model.predict(input_seq)

  
  seq_trgt = np.zeros((1, 1))
  
  
  seq_trgt[0, 0] = outputs_w2ind['<sos>']


  
  eos = outputs_w2ind['<eos>']



  
  s = np.zeros((1, dim_latent_decoder))
  c = np.zeros((1, dim_latent_decoder))


  
  sent_op = [] 
  for _ in range(trgt_lenth_mx):
    o, s, c = decoder_model.predict([seq_trgt, enc_out, s, c])
        

    
    ind = np.argmax(o.flatten())

    
    if eos == ind:
      break

    word = ''
    if ind > 0:
      word = idx2word_trans[ind]
      sent_op.append(word)

    
    seq_trgt[0, 0] = ind

  return ' '.join(sent_op)

# %%
while True:
  i = np.random.choice(len(sentences_inputs))
  input_seq = ip_encdr[i:i+1]
  translation = dcdr_seq(input_seq)
  print('--------------------------')
    
  print('English I/P:', sentences_inputs[i])
  print('Hindi Translation Predicted :', translation)
  print('Original O/P:', sentences_outputs[i])

  ans = input("Type n to discontinue    ")
  if ans and ans.lower().startswith('n'):
    break
# Out:
# --------------------------
# English I/P: This machine is superior in quality to that one.
# Hindi Translation Predicted : यह डब्बा इस वाले है बड़ा बड़ा है।
# Original O/P: यह मशीन उस मशीन से बेहतर है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: We've run out of paper for the photocopier.
# Hindi Translation Predicted : वे को को को निकल
# Original O/P: फ़ोटोकॉपियर में कागज़ खतम हो गया है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I like English and music.
# Hindi Translation Predicted : मुझे अंग्रेज़ी और संगीत पसंद हैं।
# Original O/P: मुझे अंग्रेज़ी और संगीत पसंद हैं। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: That was my mistake.
# Hindi Translation Predicted : वह मेरी ग़लती थी।
# Original O/P: वह मेरी ग़लती थी। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Do you get it?
# Hindi Translation Predicted : क्या तुम्हें समझ में आया ?
# Original O/P: क्या तुम्हें समझ में आया ? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Unless it rains, I will go, too.
# Hindi Translation Predicted : अगर बारिश नहीं होती है तो मैं भी जाऊँगा।
# Original O/P: अगर बारिश नहीं होती है तो मैं भी जाऊँगा। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: It's windy, isn't it?
# Hindi Translation Predicted : यहाँ हवा चल रही है, है ना?
# Original O/P: यहाँ हवा चल रही है, है ना? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: She declined the invitation.
# Hindi Translation Predicted : उसने आमंत्रण को स्वीकार नहीं किया।
# Original O/P: उसने आमंत्रण को स्वीकार नहीं किया। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Take your time.
# Hindi Translation Predicted : आराम से आओ।
# Original O/P: आराम से आओ। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I don't know how, but you did it.
# Hindi Translation Predicted : पता नहीं कैसे पर तुमने कर दिया।
# Original O/P: पता नहीं कैसे पर तुमने कर दिया। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I'll never forget how kind you have been.
# Hindi Translation Predicted : माफ़ नहीं नहीं नहीं नहीं नहीं नहीं
# Original O/P: मैं आपके अच्छेपन को कभी नहीं भूलूँगा। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: He pulled his son by the ear.
# Hindi Translation Predicted : उसने अपने बेटे को कान से पकड़ कर खींचा।
# Original O/P: उसने अपने बेटे को कान से पकड़ कर खींचा। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Must I write in ink?
# Hindi Translation Predicted : मुझे स्याही से ही लिखना होगा?
# Original O/P: मुझे स्याही से ही लिखना होगा? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I have a lot of work to get through today.
# Hindi Translation Predicted : मुझे आज थोड़ा थोड़ा थोड़ा थोड़ा है।
# Original O/P: मेरे पास आज बहुत काम है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I advise you not to borrow money from your friends.
# Hindi Translation Predicted : तुम्हें तुम्हें तुम्हें तुम्हें तुम्हें तुम्हें मदद करना करना पा
# Original O/P: मेरी तुम्हारे लिए यह सलाह है कि अपने दोस्तों से पैसे उधार मत लो। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: She is five years old.
# Hindi Translation Predicted : वह पाँच साल की है।
# Original O/P: वह पाँच साल की है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: You quit your job, didn't you?
# Hindi Translation Predicted : आपने अपनी नौकरी छोड़ दी, हैं ना?
# Original O/P: आपने अपनी नौकरी छोड़ दी, हैं ना? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Who broke the vase?
# Hindi Translation Predicted : गुलदान को किसने तोड़ दिया?
# Original O/P: गुलदान को किसने तोड़ दिया? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I am ashamed of having been lazy.
# Hindi Translation Predicted : मुझे अपने आलसी होने पर शर्म आती है।
# Original O/P: मुझे अपने आलसी होने पर शर्म आती है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Don't worry about us.
# Hindi Translation Predicted : हमारी चिंता मत करो।
# Original O/P: हमारी चिंता मत करो। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: The clock has just struck three.
# Hindi Translation Predicted : घड़ी पर अभी अभी तीन बजे हैं।
# Original O/P: घड़ी पर अभी अभी तीन बजे हैं। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: My father may be sleeping.
# Hindi Translation Predicted : मेरे पिता शायद सो रहे होंगे।
# Original O/P: मेरे पिता शायद सो रहे होंगे। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I know those women.
# Hindi Translation Predicted : मैं उन औरतों को जानता हूँ।
# Original O/P: मैं उन औरतों को जानता हूँ। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I had to decline his offer.
# Hindi Translation Predicted : मुझे उसके प्रस्ताव को अस्वीकार करना पड़ा।
# Original O/P: मुझे उसके प्रस्ताव को अस्वीकार करना पड़ा। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I fell down the stairs in my haste.
# Hindi Translation Predicted : अपनी ही जल्दबाज़ी मे मैं सीढ़ियों से नीचे गिर गया।
# Original O/P: अपनी ही जल्दबाज़ी मे मैं सीढ़ियों से नीचे गिर गया। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Once again.
# Hindi Translation Predicted : और एक बार।
# Original O/P: और एक बार। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Can you drive a car?
# Hindi Translation Predicted : तुम्हें गाड़ी चलाना सकते है क्या?
# Original O/P: तुम गाड़ी चला सकते हो क्या? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Some fish fly.
# Hindi Translation Predicted : कुछ मछलियाँ उड़ सकतीं हैं।
# Original O/P: कुछ मछलियाँ उड़ सकतीं हैं। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: It was her fate to die young.
# Hindi Translation Predicted : छोटी उम्र में मरना उसके भाग्य में था।
# Original O/P: छोटी उम्र में मरना उसके भाग्य में था। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I don't want to buy this kind of sofa.
# Hindi Translation Predicted : मुझे इस तरह का सोफ़ा नहीं खरीदना है।
# Original O/P: मुझे इस तरह का सोफ़ा नहीं खरीदना है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I cannot understand what happened.
# Hindi Translation Predicted : मुझे समझ में नहीं आ रहा क्या हुआ।
# Original O/P: मुझे समझ में नहीं आ रहा क्या हुआ। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: The king ordered that the prisoner should be set free.
# Hindi Translation Predicted : डॉक्टर ने ने न न पीने पीने उसने सलह सलह
# Original O/P: राजा ने हुक़्म दिया कि क़ैदी को रिहा कर दिया जाए। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: It is free of charge.
# Hindi Translation Predicted : यह मुफ़्त का है।
# Original O/P: यह मुफ़्त का है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: They made fun of Mary.
# Hindi Translation Predicted : उन्होंने मेरी का मज़ाक उड़ाया।
# Original O/P: उन्होंने मेरी का मज़ाक उड़ाया। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Have a nice time.
# Hindi Translation Predicted : मज़े करो।
# Original O/P: मज़े करो। <eos>
# Type n to discontinue    u
# --------------------------
# English I/P: I was in bed all day long yesterday.
# Hindi Translation Predicted : कल मैं पूरे दिन बिस्तर में था।
# Original O/P: कल मैं पूरे दिन बिस्तर में था। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Why have you shut the door?
# Hindi Translation Predicted : तुमने दरवाज़ा क्यों बंद कर दिया
# Original O/P: तुमने दरवाज़ा क्यों बंद कर दिया ? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: The reason why you failed is you did not try hard enough.
# Hindi Translation Predicted : मेरे उस की है जो तुम्हें कैसे कैसे
# Original O/P: तुम नाकामयाब इसलिए रहे क्योंकि तुमने पूरी तरह मेहनत नहीं लगाई। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: We all felt sorry for Tom.
# Hindi Translation Predicted : हम सब टॉम के लिए दुःखी थे।
# Original O/P: हम सब टॉम के लिए दुःखी थे। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Everyone felt sorry for Tom.
# Hindi Translation Predicted : सब टॉम के लिए दुःखी थे i
# Original O/P: सब टॉम के लिए दुःखी थे I <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Let him in.
# Hindi Translation Predicted : उसे अंदर भेजो। दो।
# Original O/P: उसे अंगर आने दो। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I visit my grandmother twice a week.
# Hindi Translation Predicted : मैं अपनी नानी से हफ़्ते में दो बार मिलने जाता हूँ।
# Original O/P: मैं अपनी नानी से हफ़्ते में दो बार मिलने जाता हूँ। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Is anybody here?
# Hindi Translation Predicted : कोई है क्या?
# Original O/P: कोई है क्या? <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: She talks a lot.
# Hindi Translation Predicted : वह बहुत बक-बक है।
# Original O/P: वह बहुत बोलती है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: The road is parallel to the river.
# Hindi Translation Predicted : वह सड़क नदी के साथ साथ चलती है।
# Original O/P: वह सड़क नदी के साथ साथ चलती है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Let's take a rest in the shade.
# Hindi Translation Predicted : चलो छाया में थोड़ा आराम करलें।
# Original O/P: चलो छाया में थोड़ा आराम करलें। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: He doesn't understand you.
# Hindi Translation Predicted : वह तुम्हें समझता नहीं है।
# Original O/P: वह तुम्हें समझता नहीं है। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: I must leave now.
# Hindi Translation Predicted : मुझे अब जाना होगा।
# Original O/P: मुझे अब जाना होगा। <eos>
# Type n to discontinue    y
# --------------------------
# English I/P: Take off your socks, please.
# Hindi Translation Predicted : अपने मोज़े उतारिए।
# Original O/P: अपने मोज़े उतारिए। <eos>
# Type n to discontinue    n
